# %% [markdown]
# # Frozen Lake

# %% [markdown]
# ### Описание задачи
#
# **Характеристики игры**
# * Эпизодическая среда
# * Стохастическая / Детерминированная среда
# * Дискретная среда
# * Среда с полной информацией
#
# **Цель игры**
# Необходимо перейти из начального состояния **S** в целевое состояние **G**,<br> пройдя только по льду **F** и избегая полыньи **H**.<br>
# Однако лед скользкий, поэтому вы не всегда будете двигаться в нужном направлении.
#
# **Окружение**
#
# <img src="http://simoninithomas.com/drlc/Qlearning/frozenlake4x4.png" />
#
# **Пространство действий**
#
# * Пойти направо
# * Пойти налево
# * Пойти вверх
# * Пойти вниз
#
# **Терминальные состояния**
# Эпизод заканчивается, когда вы достигаете цели или попадаете в полынью.
#
# **Функция вознаграждения**
# Вы получаете вознаграждение в размере 1, если вы достигнете цели, и ноль в противном случае.
#
# **Полезные ссылки**
# * https://gymnasium.farama.org/environments/toy_text/frozen_lake
# * https://gymnasium.farama.org/tutorials/training_agents/FrozenLake_tuto

# %% [markdown]
# ***

# %% [markdown]
# ### Установка зависимостей, импорт библиотек

# %% [markdown]
# **Установка зависимостей**

# %%
# !pip install gymnasium
# Out:
# Collecting gymnasium
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 10.7 MB/s eta 0:00:00
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-1.0.0

# %% [markdown]
# **Импорт библиотек**

# %%
import os
import sys
import PIL
import time
import json
import random
import numpy as np
import pandas as pd
import shutil as sh
from glob import glob
from pytz import timezone
from datetime import datetime
from google.colab import drive
from collections import deque
from base64 import b64encode
from matplotlib import pyplot as plt
from IPython.display import display, clear_output, HTML
import seaborn as sns
import gymnasium as gym

# %%
import gymnasium as gym

# %% [markdown]
# ### Подключение Google диска

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Выбор временной зоны

# %%
TZ = timezone('Europe/Moscow')

# %% [markdown]
# ### Определение путей и директорий

# %%
env_dir = '/content/drive/MyDrive/RL'
scenarios_dir = os.path.join(env_dir, 'scenarios')

# %%
if not os.path.exists(scenarios_dir):
    os.makedirs(scenarios_dir)

# %% [markdown]
# ### Вспомогательные методы

# %% [markdown]
# **Отображение состояния среды, сохранение записи эпизода, просмотр записи эпизода**

# %%
def display_state(state):
    plt.figure(figsize=(6, 6))
    plt.imshow(state)
    plt.axis('off')


def record_episode(eps_frames, records_dir, agent_name, exp_id, eps_num):
    record_path = os.path.join(records_dir, f'{agent_name}_{exp_id}_eps-{eps_num}.mp4')
    eps_frame_dir = 'episode_frames'
    os.mkdir(eps_frame_dir)

    for i, frame  in enumerate(eps_frames):
        PIL.Image.fromarray(frame).save(os.path.join(eps_frame_dir, f'frame-{i+1}.png'))

    os.system(f'ffmpeg -r 2 -i {eps_frame_dir}/frame-%1d.png -vcodec libx264 -b 10M -y "{record_path}"');
    sh.rmtree(eps_frame_dir)


def show_episode_records(records_dir):
    record_paths = glob(os.path.join(records_dir, "*.mp4"))
    html_str = ''
    for i, record_path in enumerate(record_paths):
        mp4 = open(record_path, 'rb').read()
        data = f"data:video/mp4;base64,{b64encode(mp4).decode()}"
        html_str += f'EPISODE # {i+1}<br><video width=500 controls><source src="{data}" type="video/mp4"></video><br><br>'
    return HTML(html_str)

# %% [markdown]
# **Создание директорий для логирования результатов, сохрание параметров и метрик экспериментов**

# %%
def create_exp_dirs(scenarios_dir, exp_params):
    dirs = dict()
    dirs['exp'] = os.path.join(scenarios_dir, exp_params["scenario_name"], exp_params["algorithm_name"], exp_params["exp_id"])
    dirs['training'] = os.path.join(dirs['exp'], 'training')
    dirs['evaluation'] = os.path.join(dirs['exp'], 'evaluation')
    os.makedirs(dirs['training'], exist_ok=True)
    os.makedirs(dirs['evaluation'], exist_ok=True)
    return dirs


def save_exp_params(params, exp_dir):
    params_path = os.path.join(exp_dir, 'experiment_params.json')
    with open(params_path, 'w') as f:
        json.dump(params, f)


def save_metrics(metrics, metrics_type, train_eps_dir):
    metrics_path = os.path.join(train_eps_dir, f'{metrics_type}_metrics.json')
    with open(metrics_path, 'w') as f:
        json.dump(metrics, f)

# %% [markdown]
# **Построение графика процесса валидации для выбранных экспериментов**

# %%
def display_validation_plot(scenarios_dir, scenario_name, exp_ids):
    fig = plt.figure(figsize=(10, 6))
    earliest_validation_eps = np.inf
    max_training_eps_count = 0

    for model_name in exp_ids.keys():
        for exp_id in exp_ids[model_name]:
            exp_dir = os.path.join(scenarios_dir, scenario_name, model_name, exp_id)
            exp_params_path = os.path.join(exp_dir, 'experiment_params.json')
            training_dir = os.path.join(exp_dir, 'training')

            with open(exp_params_path, 'r') as f:
                exp_params = json.load(f)
            total_eps_count = exp_params['training']['episode_count']
            validation_step = exp_params['validation']['validate_agent_every_n_eps']
            if total_eps_count > max_training_eps_count:
                max_training_eps_count = total_eps_count
            if validation_step < earliest_validation_eps:
                earliest_validation_eps = validation_step

            exp_win_shares = list()
            for iter_name in os.listdir(training_dir):
                iter_metrics_path = os.path.join(training_dir, iter_name, 'training_iter_metrics.json')
                with open(iter_metrics_path, 'r') as f:
                    iter_metrics = json.load(f)
                exp_win_shares.append(iter_metrics['win_share'])

            iter_means = np.mean(exp_win_shares, axis=0).round(3)
            iter_stds = np.std(exp_win_shares, axis=0).round(3)
            std_bounds = np.array([[avg - std, avg + std] for avg, std in list(zip(iter_means, iter_stds))])
            validation_steps = range(validation_step, total_eps_count + validation_step, validation_step)

            plt.plot(validation_steps, iter_means, label=f'{model_name} ({exp_id})')
            plt.fill_between(validation_steps, std_bounds[:,0], std_bounds[:,1], alpha=.3)

    plt.xlim(earliest_validation_eps, max_training_eps_count)
    plt.ylim(0, 1)
    plt.xlabel('Training episodes')
    plt.ylabel('Win share')
    plt.title(f'Сomparative assessment of learning process ({scenario_name})')
    plt.legend(loc='upper left')
    plt.grid()

# %% [markdown]
# **Загрузка лучшего агента из всех итераций для выбранного шага обучения**

# %%
def load_best_agent_for_train_step(train_eps_num, iteration_count, training_dir, agent):
    best_iter_num = 1
    best_win_share = 0
    best_avg_step_count = 100
    for iter_num in range(1, iteration_count+1):
        iter_dir = os.path.join(training_dir, f'iter-{iter_num}')
        eps_dir = os.path.join(iter_dir, f'eps-{train_eps_num}')
        val_metrics_path = os.path.join(eps_dir, 'validation_metrics.json')
        with open(val_metrics_path, 'r') as f:
            val_metrics = json.load(f)
        if val_metrics['win_share'] > best_win_share and val_metrics['avg_step_count'] < best_avg_step_count:
            best_iter_num = iter_num
            best_win_share = val_metrics['win_share']
            best_avg_step_count = val_metrics['avg_step_count']

    agent_state_dir = os.path.join(training_dir, f'iter-{best_iter_num}', f'eps-{train_eps_num}')
    agent.load_agent_state(agent_state_dir)

# %% [markdown]
# ## Обзор окружения

# %%
MAP_SIZE = 8
STOCHASTIC_ENV = False
ACTION_MAP = {
    'L': 0,
    'D': 1,
    'R': 2,
    'U': 3
}

def create_environment(map_size, stochastic_env):
    return gym.make('FrozenLake-v1', map_name=f'{map_size}x{map_size}', is_slippery=stochastic_env, render_mode='rgb_array')

# %% [markdown]
# ### Создание окружения, старт нового эпизода, отображение начального состояния

# %%
env = create_environment(map_size=MAP_SIZE, stochastic_env=STOCHASTIC_ENV)
state, info = env.reset()
state_rgb = env.render()

print(f'Current state: {state}')
display_state(state_rgb)
# Out:
# Current state: 0

# %% [markdown]
# ### Тестирование окружения

# %%
action_name = 'D'
action = ACTION_MAP[action_name]

next_state, reward, terminated, truncated, info = env.step(action)
next_state_rgb = env.render()

print(f'Current state: {next_state}\nReward: {reward}\nDone: {terminated, truncated}')
display_state(next_state_rgb)
# Out:
# Current state: 8
# Reward: 0.0
# Done: (False, False)

# %%
env.close()

# %% [markdown]
# ## Тестирование агента со случайной стратегией

# %% [markdown]
# ## Тестирование Q-агента в детерминированной среде

# %%
MAP_SIZE = 8
STOCHASTIC_ENV = True

# %% [markdown]
# ### Реализация агента

# %%
class QAgent:

    def __init__(self, env, params):
        self._env = env
        self._params = params
        self._epsilon = params['training']['epsilon']
        self._qtable = np.zeros((env.observation_space.n, env.action_space.n))
        self._action_arrow_map = { 0: '', 1: '←', 2: '↓', 3: '→', 4: '↑' }

    @property
    def name(self):
        return f"{self._params['algorithm_name']}_agent"

    @property
    def exploration_level(self):
        return self._epsilon


    def choose_action(self, state, mode='exploitation'):
        if mode == 'exploration':
          if np.random.rand() < self._epsilon:
              return self._env.action_space.sample()

        return np.argmax(self._qtable[state, :])


    def learn(self, state, action, next_state, reward):
        target = reward + self._params['training']['gamma'] * np.max(self._qtable[next_state, :])
        self._qtable[state, action] = self._qtable[state, action] + \
                                      self._params['training']['learning_rate'] * (target - self._qtable[state, action])


    def decrease_exploration_level(self):
        if self._epsilon > self._params['training']['epsilon_min']:
            self._epsilon *= self._params['training']['epsilon_decay_rate']


    def display_q_table(self):
        self._prepare_q_table()


    def save_q_table_as_plot(self, eps_dir):
        q_table_plot = self._prepare_q_table()
        q_table_plot_path = os.path.join(eps_dir, 'qtable.png')
        q_table_plot.savefig(q_table_plot_path, bbox_inches='tight')
        plt.close(q_table_plot)


    def save_agent_state(self, eps_dir):
        qtable_path = os.path.join(eps_dir, 'qtable.npy')
        np.save(qtable_path, self._qtable)


    def load_agent_state(self, eps_dir):
        qtable_path = os.path.join(eps_dir, 'qtable.npy')
        self._qtable = np.load(qtable_path, allow_pickle=True)


    def _prepare_q_table(self):
        greedy_values = np.max(self._qtable, axis=1).reshape(MAP_SIZE, MAP_SIZE)
        greedy_actions = np.argmax(np.hstack((np.zeros((self._env.observation_space.n, 1)), self._qtable)), axis=1)
        greedy_actions_arrows = np.array(list(map(lambda x: '' if x == 0 else self._action_arrow_map[x], greedy_actions))).reshape(MAP_SIZE, MAP_SIZE)

        fig = plt.figure()
        sns.heatmap(greedy_values,
                    annot=greedy_actions_arrows,
                    annot_kws={"fontsize": 16},
                    fmt = '',
                    cmap="YlGnBu",
                    linewidths=.5)
        plt.axis('off')
        return fig

# %% [markdown]
# ### Методы для тренировки и валидации агента

# %%
def train_agent(env, agent, exp_params, exp_dirs, enable_eps_recording):
    random.seed(exp_params['seed'])
    np.random.seed(exp_params['seed'])

    train_iter_count = len(os.listdir(exp_dirs['training']))
    train_iter_dir = os.path.join(exp_dirs['training'], f'iter-{train_iter_count+1}')
    os.mkdir(train_iter_dir)

    training_eps_count = exp_params['training']['episode_count']
    validate_agent_every_n_eps = exp_params['validation']['validate_agent_every_n_eps']
    validation_eps_count = exp_params['validation']['episode_count']

    train_metrics = {
        'total_eps_count': training_eps_count,
        'validation_step': validate_agent_every_n_eps,
        'win_share': []
    }

    for eps_num in range(1, training_eps_count + 1):
        state, info = env.reset()
        done = False

        while not done:
            action = agent.choose_action(state, mode='exploration')
            next_state, reward, terminated, truncated, info = env.step(action)
            agent.learn(state, action, next_state, reward)
            done = terminated or truncated
            state = next_state

        agent.decrease_exploration_level()

        if eps_num % validate_agent_every_n_eps == 0:
            eps_dir = os.path.join(train_iter_dir, f'eps-{eps_num}')
            os.mkdir(eps_dir)

            val_metrics = validate_agent(env, agent, exp_params, eps_dir, enable_eps_recording)
            train_metrics['win_share'].append(val_metrics['win_share'])
            agent.save_q_table_as_plot(eps_dir)
            agent.save_agent_state(eps_dir)

            print(f"EPISODE # {eps_num} / {training_eps_count}")
            print(f"Win share ({validation_eps_count} eps): {val_metrics['win_share']}")
            print(f"Avg step count ({validation_eps_count} eps): {val_metrics['avg_step_count']}")
            print(f"Aget exploration level (epsilon): {val_metrics['exploration_level']}")
            print('-' * 50)

    save_metrics(train_metrics, 'training_iter', train_iter_dir)
    return train_metrics


def validate_agent(env, agent, exp_params, train_eps_dir, enable_eps_recording):
    validation_eps_count = exp_params['validation']['episode_count']
    won_eps_count = 0
    eps_step_counts = list()

    for eps_num in range(1, validation_eps_count + 1):
        eps_final_state, eps_step_count, eps_frames = run_episode(env, agent)
        if eps_final_state == env.observation_space.n - 1:
            won_eps_count += 1
        eps_step_counts.append(eps_step_count)
        if enable_eps_recording:
            record_episode(eps_frames, train_eps_dir, exp_params['algorithm_name'], exp_params['exp_id'], eps_num)

    val_metrics = {
        'win_share': round(won_eps_count / validation_eps_count, 3),
        'avg_step_count': round(sum(eps_step_counts) / validation_eps_count, 3),
        'exploration_level': round(agent.exploration_level, 3)
    }

    save_metrics(val_metrics, 'validation', train_eps_dir)
    return val_metrics

# %% [markdown]
# ### Параметры эксперимента

# %%
exp_params = {
    'scenario_name': f'{MAP_SIZE}x{MAP_SIZE}_{"stochastic" if STOCHASTIC_ENV else "deterministic"}',
    'algorithm_name': 'qtable',
    'exp_id': f'exp-{datetime.now(TZ).strftime("%d%m-%H%M%S")}',
    'seed': 21,
    'training': {
        'iteration_count': 1,
        'episode_count': 5000,
        'learning_rate': 0.05,
        'gamma': 0.99,
        'epsilon': 1.0,
        'epsilon_min': 0.01,
        'epsilon_decay_rate': 0.99995
    },
    'validation': {
        'validate_agent_every_n_eps': 500,
        'episode_count': 10
    },
    'evaluation': {
        'episode_count': 3
    }
}

exp_dirs = create_exp_dirs(scenarios_dir, exp_params)
save_exp_params(exp_params, exp_dirs['exp'])

# %% [markdown]
# ### Обучение агента

# %%
env = create_environment(map_size=MAP_SIZE, stochastic_env=STOCHASTIC_ENV)

for iter_num in range(1, exp_params['training']['iteration_count']+1):
    print(f'TRAINING ITERATION # {iter_num}\n')
    qtable_agent = QAgent(env, exp_params)
    train_agent(env, qtable_agent, exp_params, exp_dirs, enable_eps_recording=True)
    if iter_num != exp_params['training']['iteration_count']:
        clear_output()

env.close()
# Out:
# TRAINING ITERATION # 1
#
# EPISODE # 500 / 5000
# Win share (10 eps): 0.0
# Avg step count (10 eps): 100.0
# Aget exploration level (epsilon): 0.975
# --------------------------------------------------
# EPISODE # 1000 / 5000
# Win share (10 eps): 0.0
# Avg step count (10 eps): 100.0
# Aget exploration level (epsilon): 0.951
# --------------------------------------------------
# EPISODE # 1500 / 5000
# Win share (10 eps): 0.0
# Avg step count (10 eps): 100.0
# Aget exploration level (epsilon): 0.928
# --------------------------------------------------
# EPISODE # 2000 / 5000
# Win share (10 eps): 0.0
# Avg step count (10 eps): 100.0
# Aget exploration level (epsilon): 0.905
# --------------------------------------------------
# EPISODE # 2500 / 5000
# Win share (10 eps): 0.0
# Avg step count (10 eps): 100.0
# Aget exploration level (epsilon): 0.882
# --------------------------------------------------
# EPISODE # 3000 / 5000
# Win share (10 eps): 0.1
# Avg step count (10 eps): 34.1
# Aget exploration level (epsilon): 0.861
# --------------------------------------------------
# EPISODE # 3500 / 5000
# Win share (10 eps): 0.1
# Avg step count (10 eps): 26.1
# Aget exploration level (epsilon): 0.839
# --------------------------------------------------
# EPISODE # 4000 / 5000
# Win share (10 eps): 0.3
# Avg step count (10 eps): 43.6
# Aget exploration level (epsilon): 0.819
# --------------------------------------------------
# EPISODE # 4500 / 5000
# Win share (10 eps): 0.0
# Avg step count (10 eps): 58.3
# Aget exploration level (epsilon): 0.799
# --------------------------------------------------
# EPISODE # 5000 / 5000
# Win share (10 eps): 0.5
# Avg step count (10 eps): 54.1
# Aget exploration level (epsilon): 0.779
# --------------------------------------------------

# %%
scenario_name = exp_params['scenario_name']
exp_ids = {
    exp_params['algorithm_name']: [exp_params['exp_id']]
}

display_validation_plot(scenarios_dir, scenario_name, exp_ids)

# %%
qtable_agent.display_q_table()

# %% [markdown]
# ### Оценка агента

# %% [markdown]
# ### Методы для запуска эпизодов и оценки агента

# %%
def run_episode(env, agent):
    state, info = env.reset()
    step_count = 0
    frames = list()
    done = False

    while not done:
        action = agent.choose_action(state, mode='exploitation')
        next_state, reward, terminated, truncated, info = env.step(action)
        frames.append(env.render())
        done = terminated or truncated
        state = next_state
        step_count += 1

    frames.extend([env.render()] * 3)
    return state, step_count, frames


def evaluate_agent(env, agent, exp_params, exp_dirs):
    for eps_num in range(1, exp_params['evaluation']['episode_count'] + 1):
        eps_final_state, eps_step_count, eps_frames = run_episode(env, agent)
        record_episode(eps_frames, exp_dirs['evaluation'], exp_params['algorithm_name'], exp_params['exp_id'], eps_num)

        print(f'EPISODE # {eps_num}')
        if eps_final_state == env.observation_space.n - 1:
            print('Agent reached the Goal 🏆')
        else:
            print('Agent was defeated ☠️')
        print(f'Number of steps: {eps_step_count}')
        print('-' * 50)

# %% [markdown]
# ### Параметры эксперимента

# %%
env = create_environment(map_size=MAP_SIZE, stochastic_env=STOCHASTIC_ENV)
evaluate_agent(env, qtable_agent, exp_params, exp_dirs)
env.close()
# Out:
# EPISODE # 1
# Agent was defeated ☠️
# Number of steps: 47
# --------------------------------------------------
# EPISODE # 2
# Agent was defeated ☠️
# Number of steps: 35
# --------------------------------------------------
# EPISODE # 3
# Agent was defeated ☠️
# Number of steps: 43
# --------------------------------------------------

# %%
show_episode_records(exp_dirs['evaluation'])
# Out:
# EPISODE # 1<br><video width=500 controls><source src="data:video/mp4;base64,..." type="video/mp4"></video><br><br>EPISODE # 2<br><video width=500 controls><source src="data:video/mp4;base64,..." type="video/mp4"></video><br><br>EPISODE # 3<br><video width=500 controls><source src="data:video/mp4;base64,..." type="video/mp4"></video><br><br>

# %% [markdown]
# ## Тестирование DynaQ-агента в детерминированной среде

# %%
MAP_SIZE = 8
STOCHASTIC_ENV = True

# %% [markdown]
# ### Описаниа алгоритма Dyna-Q

# %% [markdown]
# <img src="data:image/png;base64,..." style="max-width:80%; width:80%">

# %% [markdown]
# ### Реализация модели окружения

# %%
class DeterministicEnvModel:

    def __init__(self, n_states, n_actions):
        self.n_states = n_states
        self.n_actions = n_actions
        self.completed_transitions = set()
        self.transitions = np.zeros((n_states, n_actions), dtype=np.uint8)
        self.rewards = np.zeros((n_states, n_actions), dtype=np.uint8)


    def update(self, state, action, next_state, reward):
        if (state, action) not in self.completed_transitions:
            self.completed_transitions.add((state, action))
            self.transitions[state, action] = next_state
            self.rewards[state, action] = reward


    def sample(self):
        return random.choice(list(self.completed_transitions))


    def step(self, state, action):
        next_state = self.transitions[state, action]
        reward = self.rewards[state, action]
        return next_state, reward


    def display_transitions(self):
        display(HTML(pd.DataFrame(self.transitions, columns=['L', 'D', 'R', 'U']).T.to_html()))


    def display_rewards(self):
        display(HTML(pd.DataFrame(self.rewards, columns=['L', 'D', 'R', 'U']).T.to_html()))

# %% [markdown]
# ### Реализация агента

# %%
class DynaQAgent:

    def __init__(self, env, env_model_cls, params):
        self._env = env
        self._params = params
        self._epsilon = params['training']['epsilon']
        self._qtable = np.zeros((env.observation_space.n, env.action_space.n))
        self._model = env_model_cls(env.observation_space.n, env.action_space.n)
        self._action_arrow_map = { 0: '', 1: '←', 2: '↓', 3: '→', 4: '↑' }

    @property
    def name(self):
        return f"{self._params['algorithm_name']}_agent"

    @property
    def exploration_level(self):
        return self._epsilon


    def choose_action(self, state, mode='exploitation'):
        if mode == 'exploration':
          if np.random.rand() < self._epsilon:
              return self._env.action_space.sample()

        return np.argmax(self._qtable[state, :])


    def learn(self, state, action, next_state, reward):
        self._learn(state, action, next_state, reward)
        self._update_model(state, action, next_state, reward)
        self._planning(self._params['training']['planning_steps'])


    def decrease_exploration_level(self):
        if self._epsilon > self._params['training']['epsilon_min']:
            self._epsilon *= self._params['training']['epsilon_decay_rate']


    def display_q_table(self):
        self._prepare_q_table()


    def save_q_table_as_plot(self, eps_dir):
        q_table_plot = self._prepare_q_table()
        q_table_plot_path = os.path.join(eps_dir, 'qtable.png')
        q_table_plot.savefig(q_table_plot_path, bbox_inches='tight')
        plt.close(q_table_plot)


    def display_model(self):
        print(f'Transitions tabel:\n')
        self._model.display_transitions()
        print(f'\n\nRewards tabel:\n')
        self._model.display_rewards()


    def save_agent_state(self, state_dir):
        np.save(os.path.join(state_dir, 'qtable.npy'), self._qtable)
        np.save(os.path.join(state_dir, 'model_transitions.npy'), self._model.transitions)
        np.save(os.path.join(state_dir, 'model_rewards.npy'), self._model.rewards)


    def load_agent_state(self, state_dir):
        self._qtable = np.load(os.path.join(state_dir, 'qtable.npy'), allow_pickle=True)
        self._model.transitions = np.load(os.path.join(state_dir, 'model_transitions.npy'), allow_pickle=True)
        self._model.rewards = np.load(os.path.join(state_dir, 'model_rewards.npy'), allow_pickle=True)


    def _learn(self, state, action, next_state, reward):
        target = reward + self._params['training']['gamma'] * np.max(self._qtable[next_state, :])
        self._qtable[state, action] = self._qtable[state, action] + \
                                      self._params['training']['learning_rate'] * (target - self._qtable[state, action])


    def _update_model(self, state, action, next_state, reward):
        self._model.update(state, action, next_state, reward)


    def _planning(self, n_steps):
        for i in range(n_steps):
            state, action =  self._model.sample()
            next_state, reward = self._model.step(state, action)
            self._learn(state, action, next_state, reward)


    def _prepare_q_table(self):
        greedy_values = np.max(self._qtable, axis=1).reshape(MAP_SIZE, MAP_SIZE)
        greedy_actions = np.argmax(np.hstack((np.zeros((self._env.observation_space.n, 1)), self._qtable)), axis=1)
        greedy_actions_arrows = np.array(list(map(lambda x: '' if x == 0 else self._action_arrow_map[x], greedy_actions))).reshape(MAP_SIZE, MAP_SIZE)

        fig = plt.figure()
        sns.heatmap(greedy_values,
                    annot=greedy_actions_arrows,
                    annot_kws={"fontsize": 16},
                    fmt = '',
                    cmap="YlGnBu",
                    linewidths=.5)
        plt.axis('off')
        return fig

# %% [markdown]
# ### Параметры эксперимента

# %%
exp_params = {
    'scenario_name': f'{MAP_SIZE}x{MAP_SIZE}_{"stochastic" if STOCHASTIC_ENV else "deterministic"}',
    'algorithm_name': 'dynaq',
    'exp_id': f'exp-{datetime.now(TZ).strftime("%d%m-%H%M%S")}',
    'seed': 21,
    'training': {
        'iteration_count': 1,
        'episode_count': 5000,
        'learning_rate': 0.05,
        'gamma': 0.99,
        'epsilon': 1.0,
        'epsilon_min': 0.01,
        'epsilon_decay_rate': 0.99995,
        'planning_steps': 30
    },
    'validation': {
        'validate_agent_every_n_eps': 500,
        'episode_count': 10
    },
    'evaluation': {
        'episode_count': 3
    }
}

exp_dirs = create_exp_dirs(scenarios_dir, exp_params)
save_exp_params(exp_params, exp_dirs['exp'])

# %% [markdown]
# ### Обучение агента

# %%
env = create_environment(map_size=MAP_SIZE, stochastic_env=STOCHASTIC_ENV)

for iter_num in range(1, exp_params['training']['iteration_count']+1):
    print(f'TRAINING ITERATION # {iter_num}\n')
    dynaq_agent = DynaQAgent(env, DeterministicEnvModel, exp_params)
    train_agent(env, dynaq_agent, exp_params, exp_dirs, enable_eps_recording=True)
    if iter_num != exp_params['training']['iteration_count']:
        clear_output()

env.close()
# Out:
# TRAINING ITERATION # 1
#
# EPISODE # 500 / 5000
# Win share (10 eps): 0.0
# Avg step count (10 eps): 27.6
# Aget exploration level (epsilon): 0.975
# --------------------------------------------------
# EPISODE # 1000 / 5000
# Win share (10 eps): 0.0
# Avg step count (10 eps): 49.9
# Aget exploration level (epsilon): 0.951
# --------------------------------------------------
# EPISODE # 1500 / 5000
# Win share (10 eps): 0.0
# Avg step count (10 eps): 36.1
# Aget exploration level (epsilon): 0.928
# --------------------------------------------------
# EPISODE # 2000 / 5000
# Win share (10 eps): 0.0
# Avg step count (10 eps): 26.4
# Aget exploration level (epsilon): 0.905
# --------------------------------------------------
# EPISODE # 2500 / 5000
# Win share (10 eps): 0.0
# Avg step count (10 eps): 38.1
# Aget exploration level (epsilon): 0.882
# --------------------------------------------------
# EPISODE # 3000 / 5000
# Win share (10 eps): 0.0
# Avg step count (10 eps): 44.3
# Aget exploration level (epsilon): 0.861
# --------------------------------------------------
# EPISODE # 3500 / 5000
# Win share (10 eps): 0.1
# Avg step count (10 eps): 46.6
# Aget exploration level (epsilon): 0.839
# --------------------------------------------------
# EPISODE # 4000 / 5000
# Win share (10 eps): 0.0
# Avg step count (10 eps): 32.4
# Aget exploration level (epsilon): 0.819
# --------------------------------------------------
# EPISODE # 4500 / 5000
# Win share (10 eps): 0.0
# Avg step count (10 eps): 17.9
# Aget exploration level (epsilon): 0.799
# --------------------------------------------------
# EPISODE # 5000 / 5000
# Win share (10 eps): 0.0
# Avg step count (10 eps): 54.6
# Aget exploration level (epsilon): 0.779
# --------------------------------------------------

# %%
scenario_name = exp_params['scenario_name']
exp_ids = {
    exp_params['algorithm_name']: [exp_params['exp_id']]
}

display_validation_plot(scenarios_dir, scenario_name, exp_ids)

# %%
dynaq_agent.display_q_table()

# %%
dynaq_agent.display_model()
# Out:
# Transitions tabel:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>10</th>
#       <th>11</th>
#       <th>12</th>
#       <th>13</th>
#       <th>14</th>
#       <th>15</th>
#       <th>16</th>
#       <th>17</th>
#       <th>18</th>
#       <th>19</th>
#       <th>20</th>
#       <th>21</th>
#       <th>22</th>
#       <th>23</th>
#       <th>24</th>
#       <th>25</th>
#       <th>26</th>
#       <th>27</th>
#       <th>28</th>
#       <th>29</th>
#       <th>30</th>
#       <th>31</th>
#       <th>32</th>
#       <th>33</th>
#       <th>34</th>
#       <th>35</th>
#       <th>36</th>
#       <th>37</th>
#       <th>38</th>
#       <th>39</th>
#       <th>40</th>
#       <th>41</th>
#       <th>42</th>
#       <th>43</th>
#       <th>44</th>
#       <th>45</th>
#       <th>46</th>
#       <th>47</th>
#       <th>48</th>
#       <th>49</th>
#       <th>50</th>
#       <th>51</th>
#       <th>52</th>
#       <th>53</th>
#       <th>54</th>
#       <th>55</th>
#       <th>56</th>
#       <th>57</th>
#       <th>58</th>
#       <th>59</th>
#       <th>60</th>
#       <th>61</th>
#       <th>62</th>
#       <th>63</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>L</th>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>2</td>
#       <td>4</td>
#       <td>5</td>
#       <td>14</td>
#       <td>15</td>
#       <td>0</td>
#       <td>8</td>
#       <td>2</td>
#       <td>3</td>
#       <td>20</td>
#       <td>21</td>
#       <td>22</td>
#       <td>14</td>
#       <td>8</td>
#       <td>25</td>
#       <td>26</td>
#       <td>0</td>
#       <td>12</td>
#       <td>29</td>
#       <td>30</td>
#       <td>22</td>
#       <td>32</td>
#       <td>33</td>
#       <td>34</td>
#       <td>19</td>
#       <td>36</td>
#       <td>0</td>
#       <td>38</td>
#       <td>23</td>
#       <td>32</td>
#       <td>25</td>
#       <td>33</td>
#       <td>0</td>
#       <td>35</td>
#       <td>45</td>
#       <td>46</td>
#       <td>47</td>
#       <td>40</td>
#       <td>0</td>
#       <td>0</td>
#       <td>42</td>
#       <td>52</td>
#       <td>44</td>
#       <td>0</td>
#       <td>46</td>
#       <td>48</td>
#       <td>0</td>
#       <td>49</td>
#       <td>0</td>
#       <td>0</td>
#       <td>61</td>
#       <td>0</td>
#       <td>54</td>
#       <td>48</td>
#       <td>56</td>
#       <td>50</td>
#       <td>0</td>
#       <td>59</td>
#       <td>60</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>D</th>
#       <td>1</td>
#       <td>9</td>
#       <td>3</td>
#       <td>11</td>
#       <td>12</td>
#       <td>13</td>
#       <td>14</td>
#       <td>15</td>
#       <td>8</td>
#       <td>8</td>
#       <td>9</td>
#       <td>19</td>
#       <td>13</td>
#       <td>14</td>
#       <td>22</td>
#       <td>15</td>
#       <td>16</td>
#       <td>16</td>
#       <td>17</td>
#       <td>0</td>
#       <td>28</td>
#       <td>22</td>
#       <td>21</td>
#       <td>31</td>
#       <td>32</td>
#       <td>24</td>
#       <td>25</td>
#       <td>26</td>
#       <td>36</td>
#       <td>0</td>
#       <td>38</td>
#       <td>31</td>
#       <td>33</td>
#       <td>41</td>
#       <td>33</td>
#       <td>0</td>
#       <td>35</td>
#       <td>38</td>
#       <td>39</td>
#       <td>47</td>
#       <td>40</td>
#       <td>0</td>
#       <td>0</td>
#       <td>42</td>
#       <td>45</td>
#       <td>46</td>
#       <td>0</td>
#       <td>55</td>
#       <td>49</td>
#       <td>0</td>
#       <td>49</td>
#       <td>52</td>
#       <td>0</td>
#       <td>52</td>
#       <td>0</td>
#       <td>63</td>
#       <td>57</td>
#       <td>58</td>
#       <td>57</td>
#       <td>0</td>
#       <td>60</td>
#       <td>60</td>
#       <td>61</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>R</th>
#       <td>1</td>
#       <td>9</td>
#       <td>2</td>
#       <td>4</td>
#       <td>4</td>
#       <td>6</td>
#       <td>6</td>
#       <td>15</td>
#       <td>9</td>
#       <td>10</td>
#       <td>18</td>
#       <td>19</td>
#       <td>13</td>
#       <td>21</td>
#       <td>15</td>
#       <td>15</td>
#       <td>24</td>
#       <td>18</td>
#       <td>10</td>
#       <td>0</td>
#       <td>28</td>
#       <td>29</td>
#       <td>30</td>
#       <td>23</td>
#       <td>25</td>
#       <td>33</td>
#       <td>34</td>
#       <td>19</td>
#       <td>29</td>
#       <td>0</td>
#       <td>22</td>
#       <td>39</td>
#       <td>24</td>
#       <td>25</td>
#       <td>35</td>
#       <td>0</td>
#       <td>28</td>
#       <td>38</td>
#       <td>46</td>
#       <td>31</td>
#       <td>41</td>
#       <td>0</td>
#       <td>0</td>
#       <td>35</td>
#       <td>52</td>
#       <td>53</td>
#       <td>0</td>
#       <td>55</td>
#       <td>56</td>
#       <td>0</td>
#       <td>42</td>
#       <td>59</td>
#       <td>0</td>
#       <td>61</td>
#       <td>0</td>
#       <td>47</td>
#       <td>56</td>
#       <td>57</td>
#       <td>59</td>
#       <td>0</td>
#       <td>61</td>
#       <td>62</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>U</th>
#       <td>0</td>
#       <td>2</td>
#       <td>3</td>
#       <td>2</td>
#       <td>4</td>
#       <td>5</td>
#       <td>5</td>
#       <td>6</td>
#       <td>0</td>
#       <td>10</td>
#       <td>2</td>
#       <td>10</td>
#       <td>4</td>
#       <td>14</td>
#       <td>6</td>
#       <td>14</td>
#       <td>16</td>
#       <td>16</td>
#       <td>10</td>
#       <td>0</td>
#       <td>21</td>
#       <td>22</td>
#       <td>23</td>
#       <td>23</td>
#       <td>16</td>
#       <td>17</td>
#       <td>18</td>
#       <td>26</td>
#       <td>29</td>
#       <td>0</td>
#       <td>22</td>
#       <td>23</td>
#       <td>33</td>
#       <td>34</td>
#       <td>33</td>
#       <td>0</td>
#       <td>37</td>
#       <td>36</td>
#       <td>39</td>
#       <td>38</td>
#       <td>32</td>
#       <td>0</td>
#       <td>0</td>
#       <td>35</td>
#       <td>43</td>
#       <td>46</td>
#       <td>0</td>
#       <td>47</td>
#       <td>48</td>
#       <td>0</td>
#       <td>51</td>
#       <td>52</td>
#       <td>0</td>
#       <td>52</td>
#       <td>0</td>
#       <td>54</td>
#       <td>48</td>
#       <td>56</td>
#       <td>57</td>
#       <td>0</td>
#       <td>61</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# Rewards tabel:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>10</th>
#       <th>11</th>
#       <th>12</th>
#       <th>13</th>
#       <th>14</th>
#       <th>15</th>
#       <th>16</th>
#       <th>17</th>
#       <th>18</th>
#       <th>19</th>
#       <th>20</th>
#       <th>21</th>
#       <th>22</th>
#       <th>23</th>
#       <th>24</th>
#       <th>25</th>
#       <th>26</th>
#       <th>27</th>
#       <th>28</th>
#       <th>29</th>
#       <th>30</th>
#       <th>31</th>
#       <th>32</th>
#       <th>33</th>
#       <th>34</th>
#       <th>35</th>
#       <th>36</th>
#       <th>37</th>
#       <th>38</th>
#       <th>39</th>
#       <th>40</th>
#       <th>41</th>
#       <th>42</th>
#       <th>43</th>
#       <th>44</th>
#       <th>45</th>
#       <th>46</th>
#       <th>47</th>
#       <th>48</th>
#       <th>49</th>
#       <th>50</th>
#       <th>51</th>
#       <th>52</th>
#       <th>53</th>
#       <th>54</th>
#       <th>55</th>
#       <th>56</th>
#       <th>57</th>
#       <th>58</th>
#       <th>59</th>
#       <th>60</th>
#       <th>61</th>
#       <th>62</th>
#       <th>63</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>L</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>D</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>R</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>U</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Оценка агента

# %%
env = create_environment(map_size=MAP_SIZE, stochastic_env=STOCHASTIC_ENV)
evaluate_agent(env, dynaq_agent, exp_params, exp_dirs)
env.close()
# Out:
# EPISODE # 1
# Agent was defeated ☠️
# Number of steps: 49
# --------------------------------------------------
# EPISODE # 2
# Agent was defeated ☠️
# Number of steps: 36
# --------------------------------------------------
# EPISODE # 3
# Agent was defeated ☠️
# Number of steps: 19
# --------------------------------------------------

# %%
show_episode_records(exp_dirs['evaluation'])
# Out:
# EPISODE # 1<br><video width=500 controls><source src="data:video/mp4;base64,..." type="video/mp4"></video><br><br>EPISODE # 2<br><video width=500 controls><source src="data:video/mp4;base64,..." type="video/mp4"></video><br><br>EPISODE # 3<br><video width=500 controls><source src="data:video/mp4;base64,..." type="video/mp4"></video><br><br>

# %% [markdown]
# ## Тестирование DynaQ-агента в стохастической среде

# %%
MAP_SIZE = 8
STOCHASTIC_ENV = True

# %% [markdown]
# ### Реализация модели окружения (Домашнее задание!)
#
# Необходимо реализовать класс *StochasticEnvModel* для моделирования стохастической версии окружения, за основу можно взять класс *DeterministicEnvModel*.

# %%
class StochasticEnvModel:

    def __init__(self, n_states, n_actions):
        raise NotImplementedError(f'Please implement this constructor.')


    def update(self, state, action, next_state, reward):
        raise NotImplementedError(f'Please implement this method.')


    def sample(self):
        raise NotImplementedError(f'Please implement this method.')


    def step(self, state, action):
        raise NotImplementedError(f'Please implement this method.')


    def display_transitions(self):
        raise NotImplementedError(f'Please implement this method.')


    def display_rewards(self):
        raise NotImplementedError(f'Please implement this method.')

# %%
import numpy as np
from collections import defaultdict

class StochasticEnvModel:
    def __init__(self, n_states, n_actions):
        self.n_states = n_states
        self.n_actions = n_actions

        # Инициализируем словари для хранения данных
        self.transitions = {}
        self.rewards = {}
        self.transition_probs = {}

    def _ensure_state_action_exists(self, state, action):
        if state not in self.transitions:
            self.transitions[state] = {}
            self.rewards[state] = {}
            self.transition_probs[state] = {}

        if action not in self.transitions[state]:
            self.transitions[state][action] = {}
            self.rewards[state][action] = []
            self.transition_probs[state][action] = {}

    def update(self, state, action, next_state, reward):
        self._ensure_state_action_exists(state, action)

        # Обновляем счетчик переходов
        if next_state not in self.transitions[state][action]:
            self.transitions[state][action][next_state] = 0
        self.transitions[state][action][next_state] += 1

        # Сохраняем награду
        self.rewards[state][action].append(reward)

        # Обновляем вероятности переходов
        total_transitions = sum(self.transitions[state][action].values())
        for ns in self.transitions[state][action]:
            self.transition_probs[state][action][ns] = (
                self.transitions[state][action][ns] / total_transitions
            )

    def sample(self):
        if self.transitions:
            state = np.random.choice(list(self.transitions.keys()))
            if self.transitions[state]:
                action = np.random.choice(list(self.transitions[state].keys()))
            else:
                action = np.random.randint(0, self.n_actions)
        else:
            state = np.random.randint(0, self.n_states)
            action = np.random.randint(0, self.n_actions)

        return state, action

    def step(self, state, action):
        # Если переход не наблюдался, возвращаем случайное состояние
        if (state not in self.transitions or
            action not in self.transitions[state] or
            not self.transitions[state][action]):
            return np.random.randint(0, self.n_states), 0.0

        # Выбираем следующее состояние на основе вероятностей переходов
        next_states = list(self.transition_probs[state][action].keys())
        probs = list(self.transition_probs[state][action].values())
        next_state = np.random.choice(next_states, p=probs)

        # Выбираем случайную награду из наблюдаемых для данного перехода
        if self.rewards[state][action]:
            reward = np.random.choice(self.rewards[state][action])
        else:
            reward = 0.0

        return next_state, reward

    def display_transitions(self):
        print("Transitions:")
        for state in sorted(self.transitions.keys()):
            for action in sorted(self.transitions[state].keys()):
                print(f"\nState {state}, Action {action}:")
                total = sum(self.transitions[state][action].values())
                for next_state, count in sorted(self.transitions[state][action].items()):
                    prob = count / total
                    print(f"  → State {next_state}: {count} times (prob: {prob:.2f})")

    def display_rewards(self):
        print("Rewards:")
        for state in sorted(self.rewards.keys()):
            for action in sorted(self.rewards[state].keys()):
                rewards = self.rewards[state][action]
                if rewards:
                    mean_reward = np.mean(rewards)
                    std_reward = np.std(rewards)
                    print(f"\nState {state}, Action {action}:")
                    print(f"  Mean: {mean_reward:.2f}")
                    print(f"  Std: {std_reward:.2f}")
                    print(f"  Min: {min(rewards):.2f}")
                    print(f"  Max: {max(rewards):.2f}")

# %% [markdown]
# ### Параметры эксперимента

# %%
exp_params = {
    'scenario_name': f'{MAP_SIZE}x{MAP_SIZE}_{"stochastic" if STOCHASTIC_ENV else "deterministic"}',
    'algorithm_name': 'dynaq',
    'exp_id': f'exp-{datetime.now(TZ).strftime("%d%m-%H%M%S")}',
    'seed': 21,
    'training': {
        'iteration_count': 5,
        'episode_count': 5000,
        'learning_rate': 0.05,
        'gamma': 0.99,
        'epsilon': 1.0,
        'epsilon_min': 0.01,
        'epsilon_decay_rate': 0.99995,
        'planning_steps': 30
    },
    'validation': {
        'validate_agent_every_n_eps': 500,
        'episode_count': 10
    },
    'evaluation': {
        'episode_count': 3
    }
}

exp_dirs = create_exp_dirs(scenarios_dir, exp_params)
save_exp_params(exp_params, exp_dirs['exp'])

# %% [markdown]
# ### Обучение агента

# %%
# Создаем окружение
env = create_environment(map_size=MAP_SIZE, stochastic_env=STOCHASTIC_ENV)

for iter_num in range(1, exp_params['training']['iteration_count']+1):
    print(f'TRAINING ITERATION # {iter_num}\n')

    # Передаем класс модели, а не экземпляр
    dynaq_agent = DynaQAgent(env, StochasticEnvModel, exp_params)
    train_agent(env, dynaq_agent, exp_params, exp_dirs, enable_eps_recording=True)

    if iter_num != exp_params['training']['iteration_count']:
        clear_output()

env.close()
# Out:
# TRAINING ITERATION # 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-94d7ff79fba5> in <cell line: 4>()
#       7     # Передаем класс модели, а не экземпляр
#       8     dynaq_agent = DynaQAgent(env, StochasticEnvModel, exp_params)
# ----> 9     train_agent(env, dynaq_agent, exp_params, exp_dirs, enable_eps_recording=True)
#      10
#      11     if iter_num != exp_params['training']['iteration_count']:
#
# <ipython-input-32-c585bb0f2869> in train_agent(env, agent, exp_params, exp_dirs, enable_eps_recording)
#      24             action = agent.choose_action(state, mode='exploration')
#      25             next_state, reward, terminated, truncated, info = env.step(action)
# ---> 26             agent.learn(state, action, next_state, reward)
#      27             done = terminated or truncated
#      28             state = next_state
#
# <ipython-input-42-911d6a2d1890> in learn(self, state, action, next_state, reward)
#      29         self._learn(state, action, next_state, reward)
#      30         self._update_model(state, action, next_state, reward)
# ---> 31         self._planning(self._params['training']['planning_steps'])
#      32
#      33
#
# <ipython-input-42-911d6a2d1890> in _planning(self, n_steps)
#      80         for i in range(n_steps):
#      81             state, action =  self._model.sample()
# ---> 82             next_state, reward = self._model.step(state, action)
#      83             self._learn(state, action, next_state, reward)
#      84
#
# <ipython-input-60-41bf186847e7> in step(self, state, action)
#     101         next_states = list(self.transition_probs[state][action].keys())
#     102         probs = list(self.transition_probs[state][action].values())
# --> 103         next_state = np.random.choice(next_states, p=probs)
#     104
#     105         # Выбираем случайную награду из наблюдаемых для данного перехода
#
# KeyboardInterrupt:

# %%
dynaq_agent.display_q_table()

# %%
dynaq_agent.display_model()
# Out:
# Transitions tabel:
#
# Transitions:
#
# State 0, Action 0:
#   → State 0: 194 times (prob: 0.65)
#   → State 8: 103 times (prob: 0.35)
#
# State 0, Action 1:
#   → State 0: 119 times (prob: 0.36)
#   → State 1: 97 times (prob: 0.30)
#   → State 8: 111 times (prob: 0.34)
#
# State 0, Action 2:
#   → State 0: 110 times (prob: 0.35)
#   → State 1: 93 times (prob: 0.29)
#   → State 8: 114 times (prob: 0.36)
#
# State 0, Action 3:
#   → State 0: 211 times (prob: 0.67)
#   → State 1: 106 times (prob: 0.33)
#
# State 1, Action 0:
#   → State 0: 62 times (prob: 0.36)
#   → State 1: 47 times (prob: 0.27)
#   → State 9: 63 times (prob: 0.37)
#
# State 1, Action 1:
#   → State 0: 59 times (prob: 0.34)
#   → State 2: 60 times (prob: 0.34)
#   → State 9: 57 times (prob: 0.32)
#
# State 1, Action 2:
#   → State 1: 67 times (prob: 0.34)
#   → State 2: 63 times (prob: 0.32)
#   → State 9: 70 times (prob: 0.35)
#
# State 1, Action 3:
#   → State 0: 47 times (prob: 0.29)
#   → State 1: 53 times (prob: 0.33)
#   → State 2: 63 times (prob: 0.39)
#
# State 2, Action 0:
#   → State 1: 30 times (prob: 0.29)
#   → State 2: 31 times (prob: 0.30)
#   → State 10: 43 times (prob: 0.41)
#
# State 2, Action 1:
#   → State 1: 43 times (prob: 0.39)
#   → State 3: 33 times (prob: 0.30)
#   → State 10: 35 times (prob: 0.32)
#
# State 2, Action 2:
#   → State 2: 40 times (prob: 0.38)
#   → State 3: 37 times (prob: 0.35)
#   → State 10: 28 times (prob: 0.27)
#
# State 2, Action 3:
#   → State 1: 35 times (prob: 0.32)
#   → State 2: 33 times (prob: 0.30)
#   → State 3: 41 times (prob: 0.38)
#
# State 3, Action 0:
#   → State 2: 14 times (prob: 0.21)
#   → State 3: 31 times (prob: 0.46)
#   → State 11: 23 times (prob: 0.34)
#
# State 3, Action 1:
#   → State 2: 20 times (prob: 0.28)
#   → State 4: 23 times (prob: 0.32)
#   → State 11: 28 times (prob: 0.39)
#
# State 3, Action 2:
#   → State 3: 30 times (prob: 0.38)
#   → State 4: 24 times (prob: 0.30)
#   → State 11: 25 times (prob: 0.32)
#
# State 3, Action 3:
#   → State 2: 18 times (prob: 0.27)
#   → State 3: 21 times (prob: 0.32)
#   → State 4: 27 times (prob: 0.41)
#
# State 4, Action 0:
#   → State 3: 12 times (prob: 0.24)
#   → State 4: 21 times (prob: 0.43)
#   → State 12: 16 times (prob: 0.33)
#
# State 4, Action 1:
#   → State 3: 16 times (prob: 0.43)
#   → State 5: 9 times (prob: 0.24)
#   → State 12: 12 times (prob: 0.32)
#
# State 4, Action 2:
#   → State 4: 19 times (prob: 0.45)
#   → State 5: 9 times (prob: 0.21)
#   → State 12: 14 times (prob: 0.33)
#
# State 4, Action 3:
#   → State 3: 17 times (prob: 0.29)
#   → State 4: 21 times (prob: 0.36)
#   → State 5: 21 times (prob: 0.36)
#
# State 5, Action 0:
#   → State 4: 8 times (prob: 0.22)
#   → State 5: 15 times (prob: 0.41)
#   → State 13: 14 times (prob: 0.38)
#
# State 5, Action 1:
#   → State 4: 4 times (prob: 0.17)
#   → State 6: 14 times (prob: 0.58)
#   → State 13: 6 times (prob: 0.25)
#
# State 5, Action 2:
#   → State 5: 9 times (prob: 0.36)
#   → State 6: 10 times (prob: 0.40)
#   → State 13: 6 times (prob: 0.24)
#
# State 5, Action 3:
#   → State 4: 12 times (prob: 0.41)
#   → State 5: 11 times (prob: 0.38)
#   → State 6: 6 times (prob: 0.21)
#
# State 6, Action 0:
#   → State 5: 7 times (prob: 0.41)
#   → State 6: 7 times (prob: 0.41)
#   → State 14: 3 times (prob: 0.18)
#
# State 6, Action 1:
#   → State 5: 5 times (prob: 0.25)
#   → State 7: 13 times (prob: 0.65)
#   → State 14: 2 times (prob: 0.10)
#
# State 6, Action 2:
#   → State 6: 12 times (prob: 0.40)
#   → State 7: 9 times (prob: 0.30)
#   → State 14: 9 times (prob: 0.30)
#
# State 6, Action 3:
#   → State 5: 12 times (prob: 0.38)
#   → State 6: 6 times (prob: 0.19)
#   → State 7: 14 times (prob: 0.44)
#
# State 7, Action 0:
#   → State 6: 11 times (prob: 0.38)
#   → State 7: 7 times (prob: 0.24)
#   → State 15: 11 times (prob: 0.38)
#
# State 7, Action 1:
#   → State 6: 11 times (prob: 0.35)
#   → State 7: 11 times (prob: 0.35)
#   → State 15: 9 times (prob: 0.29)
#
# State 7, Action 2:
#   → State 7: 21 times (prob: 0.84)
#   → State 15: 4 times (prob: 0.16)
#
# State 7, Action 3:
#   → State 6: 9 times (prob: 0.36)
#   → State 7: 16 times (prob: 0.64)
#
# State 8, Action 0:
#   → State 0: 65 times (prob: 0.34)
#   → State 8: 66 times (prob: 0.34)
#   → State 16: 62 times (prob: 0.32)
#
# State 8, Action 1:
#   → State 8: 72 times (prob: 0.33)
#   → State 9: 67 times (prob: 0.31)
#   → State 16: 76 times (prob: 0.35)
#
# State 8, Action 2:
#   → State 0: 76 times (prob: 0.38)
#   → State 9: 69 times (prob: 0.35)
#   → State 16: 54 times (prob: 0.27)
#
# State 8, Action 3:
#   → State 0: 71 times (prob: 0.36)
#   → State 8: 66 times (prob: 0.34)
#   → State 9: 60 times (prob: 0.30)
#
# State 9, Action 0:
#   → State 1: 37 times (prob: 0.26)
#   → State 8: 53 times (prob: 0.37)
#   → State 17: 54 times (prob: 0.38)
#
# State 9, Action 1:
#   → State 8: 47 times (prob: 0.34)
#   → State 10: 50 times (prob: 0.36)
#   → State 17: 42 times (prob: 0.30)
#
# State 9, Action 2:
#   → State 1: 47 times (prob: 0.35)
#   → State 10: 45 times (prob: 0.33)
#   → State 17: 43 times (prob: 0.32)
#
# State 9, Action 3:
#   → State 1: 56 times (prob: 0.39)
#   → State 8: 44 times (prob: 0.30)
#   → State 10: 45 times (prob: 0.31)
#
# State 10, Action 0:
#   → State 2: 29 times (prob: 0.30)
#   → State 9: 37 times (prob: 0.38)
#   → State 18: 32 times (prob: 0.33)
#
# State 10, Action 1:
#   → State 9: 22 times (prob: 0.27)
#   → State 11: 27 times (prob: 0.33)
#   → State 18: 32 times (prob: 0.40)
#
# State 10, Action 2:
#   → State 2: 28 times (prob: 0.35)
#   → State 11: 28 times (prob: 0.35)
#   → State 18: 23 times (prob: 0.29)
#
# State 10, Action 3:
#   → State 2: 30 times (prob: 0.32)
#   → State 9: 36 times (prob: 0.39)
#   → State 11: 27 times (prob: 0.29)
#
# State 11, Action 0:
#   → State 3: 11 times (prob: 0.26)
#   → State 10: 20 times (prob: 0.48)
#   → State 19: 11 times (prob: 0.26)
#
# State 11, Action 1:
#   → State 10: 14 times (prob: 0.26)
#   → State 12: 21 times (prob: 0.39)
#   → State 19: 19 times (prob: 0.35)
#
# State 11, Action 2:
#   → State 3: 19 times (prob: 0.40)
#   → State 12: 16 times (prob: 0.33)
#   → State 19: 13 times (prob: 0.27)
#
# State 11, Action 3:
#   → State 3: 16 times (prob: 0.31)
#   → State 10: 17 times (prob: 0.33)
#   → State 12: 18 times (prob: 0.35)
#
# State 12, Action 0:
#   → State 4: 8 times (prob: 0.26)
#   → State 11: 9 times (prob: 0.29)
#   → State 20: 14 times (prob: 0.45)
#
# State 12, Action 1:
#   → State 11: 15 times (prob: 0.34)
#   → State 13: 12 times (prob: 0.27)
#   → State 20: 17 times (prob: 0.39)
#
# State 12, Action 2:
#   → State 4: 9 times (prob: 0.33)
#   → State 13: 5 times (prob: 0.19)
#   → State 20: 13 times (prob: 0.48)
#
# State 12, Action 3:
#   → State 4: 11 times (prob: 0.32)
#   → State 11: 13 times (prob: 0.38)
#   → State 13: 10 times (prob: 0.29)
#
# State 13, Action 0:
#   → State 5: 10 times (prob: 0.62)
#   → State 12: 4 times (prob: 0.25)
#   → State 21: 2 times (prob: 0.12)
#
# State 13, Action 1:
#   → State 12: 10 times (prob: 0.42)
#   → State 14: 10 times (prob: 0.42)
#   → State 21: 4 times (prob: 0.17)
#
# State 13, Action 2:
#   → State 5: 5 times (prob: 0.21)
#   → State 14: 11 times (prob: 0.46)
#   → State 21: 8 times (prob: 0.33)
#
# State 13, Action 3:
#   → State 5: 2 times (prob: 0.12)
#   → State 12: 11 times (prob: 0.65)
#   → State 14: 4 times (prob: 0.24)
#
# State 14, Action 0:
#   → State 6: 4 times (prob: 0.31)
#   → State 13: 7 times (prob: 0.54)
#   → State 22: 2 times (prob: 0.15)
#
# State 14, Action 1:
#   → State 13: 4 times (prob: 0.22)
#   → State 15: 10 times (prob: 0.56)
#   → State 22: 4 times (prob: 0.22)
#
# State 14, Action 2:
#   → State 6: 5 times (prob: 0.36)
#   → State 15: 7 times (prob: 0.50)
#   → State 22: 2 times (prob: 0.14)
#
# State 14, Action 3:
#   → State 6: 4 times (prob: 0.29)
#   → State 13: 6 times (prob: 0.43)
#   → State 15: 4 times (prob: 0.29)
#
# State 15, Action 0:
#   → State 7: 10 times (prob: 0.48)
#   → State 14: 6 times (prob: 0.29)
#   → State 23: 5 times (prob: 0.24)
#
# State 15, Action 1:
#   → State 14: 6 times (prob: 0.33)
#   → State 15: 4 times (prob: 0.22)
#   → State 23: 8 times (prob: 0.44)
#
# State 15, Action 2:
#   → State 7: 7 times (prob: 0.47)
#   → State 15: 4 times (prob: 0.27)
#   → State 23: 4 times (prob: 0.27)
#
# State 15, Action 3:
#   → State 7: 3 times (prob: 0.38)
#   → State 14: 3 times (prob: 0.38)
#   → State 15: 2 times (prob: 0.25)
#
# State 16, Action 0:
#   → State 8: 48 times (prob: 0.36)
#   → State 16: 51 times (prob: 0.38)
#   → State 24: 34 times (prob: 0.26)
#
# State 16, Action 1:
#   → State 16: 45 times (prob: 0.35)
#   → State 17: 49 times (prob: 0.39)
#   → State 24: 33 times (prob: 0.26)
#
# State 16, Action 2:
#   → State 8: 45 times (prob: 0.36)
#   → State 17: 45 times (prob: 0.36)
#   → State 24: 35 times (prob: 0.28)
#
# State 16, Action 3:
#   → State 8: 35 times (prob: 0.36)
#   → State 16: 38 times (prob: 0.39)
#   → State 17: 24 times (prob: 0.25)
#
# State 17, Action 0:
#   → State 9: 25 times (prob: 0.27)
#   → State 16: 33 times (prob: 0.36)
#   → State 25: 33 times (prob: 0.36)
#
# State 17, Action 1:
#   → State 16: 31 times (prob: 0.34)
#   → State 18: 35 times (prob: 0.38)
#   → State 25: 26 times (prob: 0.28)
#
# State 17, Action 2:
#   → State 9: 31 times (prob: 0.37)
#   → State 18: 26 times (prob: 0.31)
#   → State 25: 27 times (prob: 0.32)
#
# State 17, Action 3:
#   → State 9: 26 times (prob: 0.29)
#   → State 16: 31 times (prob: 0.34)
#   → State 18: 34 times (prob: 0.37)
#
# State 18, Action 0:
#   → State 10: 20 times (prob: 0.36)
#   → State 17: 17 times (prob: 0.30)
#   → State 26: 19 times (prob: 0.34)
#
# State 18, Action 1:
#   → State 17: 17 times (prob: 0.34)
#   → State 19: 14 times (prob: 0.28)
#   → State 26: 19 times (prob: 0.38)
#
# State 18, Action 2:
#   → State 10: 20 times (prob: 0.39)
#   → State 19: 12 times (prob: 0.24)
#   → State 26: 19 times (prob: 0.37)
#
# State 18, Action 3:
#   → State 10: 14 times (prob: 0.26)
#   → State 17: 13 times (prob: 0.24)
#   → State 19: 27 times (prob: 0.50)
#
# State 20, Action 0:
#   → State 12: 5 times (prob: 0.31)
#   → State 19: 8 times (prob: 0.50)
#   → State 28: 3 times (prob: 0.19)
#
# State 20, Action 1:
#   → State 19: 4 times (prob: 0.24)
#   → State 21: 7 times (prob: 0.41)
#   → State 28: 6 times (prob: 0.35)
#
# State 20, Action 2:
#   → State 12: 4 times (prob: 0.29)
#   → State 21: 3 times (prob: 0.21)
#   → State 28: 7 times (prob: 0.50)
#
# State 20, Action 3:
#   → State 12: 5 times (prob: 0.29)
#   → State 19: 5 times (prob: 0.29)
#   → State 21: 7 times (prob: 0.41)
#
# State 21, Action 0:
#   → State 13: 4 times (prob: 0.36)
#   → State 20: 5 times (prob: 0.45)
#   → State 29: 2 times (prob: 0.18)
#
# State 21, Action 1:
#   → State 20: 5 times (prob: 0.56)
#   → State 22: 3 times (prob: 0.33)
#   → State 29: 1 times (prob: 0.11)
#
# State 21, Action 2:
#   → State 13: 3 times (prob: 0.30)
#   → State 22: 5 times (prob: 0.50)
#   → State 29: 2 times (prob: 0.20)
#
# State 21, Action 3:
#   → State 13: 4 times (prob: 0.33)
#   → State 20: 5 times (prob: 0.42)
#   → State 22: 3 times (prob: 0.25)
#
# State 22, Action 0:
#   → State 14: 1 times (prob: 0.11)
#   → State 21: 5 times (prob: 0.56)
#   → State 30: 3 times (prob: 0.33)
#
# State 22, Action 1:
#   → State 21: 3 times (prob: 0.43)
#   → State 23: 3 times (prob: 0.43)
#   → State 30: 1 times (prob: 0.14)
#
# State 22, Action 2:
#   → State 14: 2 times (prob: 0.33)
#   → State 23: 2 times (prob: 0.33)
#   → State 30: 2 times (prob: 0.33)
#
# State 22, Action 3:
#   → State 14: 3 times (prob: 0.38)
#   → State 21: 3 times (prob: 0.38)
#   → State 23: 2 times (prob: 0.25)
#
# State 23, Action 0:
#   → State 15: 2 times (prob: 0.29)
#   → State 22: 4 times (prob: 0.57)
#   → State 31: 1 times (prob: 0.14)
#
# State 23, Action 1:
#   → State 22: 6 times (prob: 0.35)
#   → State 23: 2 times (prob: 0.12)
#   → State 31: 9 times (prob: 0.53)
#
# State 23, Action 2:
#   → State 15: 3 times (prob: 0.43)
#   → State 23: 1 times (prob: 0.14)
#   → State 31: 3 times (prob: 0.43)
#
# State 23, Action 3:
#   → State 15: 2 times (prob: 0.29)
#   → State 23: 5 times (prob: 0.71)
#
# State 24, Action 0:
#   → State 16: 25 times (prob: 0.40)
#   → State 24: 21 times (prob: 0.33)
#   → State 32: 17 times (prob: 0.27)
#
# State 24, Action 1:
#   → State 24: 20 times (prob: 0.30)
#   → State 25: 23 times (prob: 0.34)
#   → State 32: 24 times (prob: 0.36)
#
# State 24, Action 2:
#   → State 16: 19 times (prob: 0.38)
#   → State 25: 16 times (prob: 0.32)
#   → State 32: 15 times (prob: 0.30)
#
# State 24, Action 3:
#   → State 16: 18 times (prob: 0.32)
#   → State 24: 16 times (prob: 0.29)
#   → State 25: 22 times (prob: 0.39)
#
# State 25, Action 0:
#   → State 17: 24 times (prob: 0.39)
#   → State 24: 21 times (prob: 0.34)
#   → State 33: 16 times (prob: 0.26)
#
# State 25, Action 1:
#   → State 24: 12 times (prob: 0.21)
#   → State 26: 22 times (prob: 0.39)
#   → State 33: 23 times (prob: 0.40)
#
# State 25, Action 2:
#   → State 17: 13 times (prob: 0.31)
#   → State 26: 15 times (prob: 0.36)
#   → State 33: 14 times (prob: 0.33)
#
# State 25, Action 3:
#   → State 17: 17 times (prob: 0.33)
#   → State 24: 18 times (prob: 0.35)
#   → State 26: 17 times (prob: 0.33)
#
# State 26, Action 0:
#   → State 18: 8 times (prob: 0.25)
#   → State 25: 14 times (prob: 0.44)
#   → State 34: 10 times (prob: 0.31)
#
# State 26, Action 1:
#   → State 25: 11 times (prob: 0.34)
#   → State 27: 12 times (prob: 0.38)
#   → State 34: 9 times (prob: 0.28)
#
# State 26, Action 2:
#   → State 18: 11 times (prob: 0.34)
#   → State 27: 9 times (prob: 0.28)
#   → State 34: 12 times (prob: 0.38)
#
# State 26, Action 3:
#   → State 18: 10 times (prob: 0.27)
#   → State 25: 13 times (prob: 0.35)
#   → State 27: 14 times (prob: 0.38)
#
# State 27, Action 0:
#   → State 19: 5 times (prob: 0.45)
#   → State 26: 3 times (prob: 0.27)
#   → State 35: 3 times (prob: 0.27)
#
# State 27, Action 1:
#   → State 26: 4 times (prob: 0.24)
#   → State 28: 6 times (prob: 0.35)
#   → State 35: 7 times (prob: 0.41)
#
# State 27, Action 2:
#   → State 19: 2 times (prob: 0.22)
#   → State 28: 3 times (prob: 0.33)
#   → State 35: 4 times (prob: 0.44)
#
# State 27, Action 3:
#   → State 19: 2 times (prob: 0.29)
#   → State 26: 2 times (prob: 0.29)
#   → State 28: 3 times (prob: 0.43)
#
# State 28, Action 0:
#   → State 20: 2 times (prob: 0.33)
#   → State 27: 3 times (prob: 0.50)
#   → State 36: 1 times (prob: 0.17)
#
# State 28, Action 1:
#   → State 27: 3 times (prob: 0.27)
#   → State 29: 5 times (prob: 0.45)
#   → State 36: 3 times (prob: 0.27)
#
# State 28, Action 2:
#   → State 20: 1 times (prob: 0.14)
#   → State 29: 3 times (prob: 0.43)
#   → State 36: 3 times (prob: 0.43)
#
# State 28, Action 3:
#   → State 20: 2 times (prob: 0.29)
#   → State 27: 3 times (prob: 0.43)
#   → State 29: 2 times (prob: 0.29)
#
# State 30, Action 0:
#   → State 29: 2 times (prob: 0.67)
#   → State 38: 1 times (prob: 0.33)
#
# State 30, Action 1:
#   → State 29: 1 times (prob: 0.20)
#   → State 31: 3 times (prob: 0.60)
#   → State 38: 1 times (prob: 0.20)
#
# State 30, Action 2:
#   → State 38: 1 times (prob: 1.00)
#
# State 30, Action 3:
#   → State 22: 1 times (prob: 0.14)
#   → State 29: 3 times (prob: 0.43)
#   → State 31: 3 times (prob: 0.43)
#
# State 31, Action 0:
#   → State 23: 2 times (prob: 0.25)
#   → State 30: 3 times (prob: 0.38)
#   → State 39: 3 times (prob: 0.38)
#
# State 31, Action 1:
#   → State 30: 3 times (prob: 0.27)
#   → State 31: 4 times (prob: 0.36)
#   → State 39: 4 times (prob: 0.36)
#
# State 31, Action 2:
#   → State 23: 3 times (prob: 0.33)
#   → State 31: 2 times (prob: 0.22)
#   → State 39: 4 times (prob: 0.44)
#
# State 31, Action 3:
#   → State 23: 1 times (prob: 0.20)
#   → State 30: 2 times (prob: 0.40)
#   → State 31: 2 times (prob: 0.40)
#
# State 32, Action 0:
#   → State 24: 12 times (prob: 0.40)
#   → State 32: 10 times (prob: 0.33)
#   → State 40: 8 times (prob: 0.27)
#
# State 32, Action 1:
#   → State 32: 10 times (prob: 0.28)
#   → State 33: 13 times (prob: 0.36)
#   → State 40: 13 times (prob: 0.36)
#
# State 32, Action 2:
#   → State 24: 6 times (prob: 0.26)
#   → State 33: 7 times (prob: 0.30)
#   → State 40: 10 times (prob: 0.43)
#
# State 32, Action 3:
#   → State 24: 9 times (prob: 0.33)
#   → State 32: 9 times (prob: 0.33)
#   → State 33: 9 times (prob: 0.33)
#
# State 33, Action 0:
#   → State 25: 13 times (prob: 0.36)
#   → State 32: 8 times (prob: 0.22)
#   → State 41: 15 times (prob: 0.42)
#
# State 33, Action 1:
#   → State 32: 4 times (prob: 0.24)
#   → State 34: 5 times (prob: 0.29)
#   → State 41: 8 times (prob: 0.47)
#
# State 33, Action 2:
#   → State 25: 8 times (prob: 0.30)
#   → State 34: 10 times (prob: 0.37)
#   → State 41: 9 times (prob: 0.33)
#
# State 33, Action 3:
#   → State 25: 7 times (prob: 0.32)
#   → State 32: 6 times (prob: 0.27)
#   → State 34: 9 times (prob: 0.41)
#
# State 34, Action 0:
#   → State 26: 5 times (prob: 0.26)
#   → State 33: 9 times (prob: 0.47)
#   → State 42: 5 times (prob: 0.26)
#
# State 34, Action 1:
#   → State 33: 4 times (prob: 0.44)
#   → State 35: 2 times (prob: 0.22)
#   → State 42: 3 times (prob: 0.33)
#
# State 34, Action 2:
#   → State 26: 2 times (prob: 0.22)
#   → State 35: 6 times (prob: 0.67)
#   → State 42: 1 times (prob: 0.11)
#
# State 34, Action 3:
#   → State 26: 6 times (prob: 0.33)
#   → State 33: 7 times (prob: 0.39)
#   → State 35: 5 times (prob: 0.28)
#
# State 36, Action 0:
#   → State 28: 1 times (prob: 0.50)
#   → State 35: 1 times (prob: 0.50)
#
# State 36, Action 1:
#   → State 37: 1 times (prob: 0.50)
#   → State 44: 1 times (prob: 0.50)
#
# State 36, Action 2:
#   → State 28: 1 times (prob: 0.33)
#   → State 37: 1 times (prob: 0.33)
#   → State 44: 1 times (prob: 0.33)
#
# State 36, Action 3:
#   → State 28: 1 times (prob: 1.00)
#
# State 37, Action 1:
#   → State 38: 1 times (prob: 1.00)
#
# State 37, Action 3:
#   → State 29: 1 times (prob: 0.50)
#   → State 38: 1 times (prob: 0.50)
#
# State 38, Action 0:
#   → State 46: 1 times (prob: 1.00)
#
# State 38, Action 1:
#   → State 39: 2 times (prob: 0.67)
#   → State 46: 1 times (prob: 0.33)
#
# State 38, Action 2:
#   → State 30: 1 times (prob: 0.25)
#   → State 39: 2 times (prob: 0.50)
#   → State 46: 1 times (prob: 0.25)
#
# State 38, Action 3:
#   → State 30: 1 times (prob: 0.33)
#   → State 37: 1 times (prob: 0.33)
#   → State 39: 1 times (prob: 0.33)
#
# State 39, Action 0:
#   → State 31: 1 times (prob: 0.50)
#   → State 47: 1 times (prob: 0.50)
#
# State 39, Action 1:
#   → State 38: 2 times (prob: 0.29)
#   → State 39: 2 times (prob: 0.29)
#   → State 47: 3 times (prob: 0.43)
#
# State 39, Action 2:
#   → State 31: 4 times (prob: 0.67)
#   → State 39: 1 times (prob: 0.17)
#   → State 47: 1 times (prob: 0.17)
#
# State 39, Action 3:
#   → State 31: 1 times (prob: 0.14)
#   → State 38: 4 times (prob: 0.57)
#   → State 39: 2 times (prob: 0.29)
#
# State 40, Action 0:
#   → State 40: 3 times (prob: 0.38)
#   → State 48: 5 times (prob: 0.62)
#
# State 40, Action 1:
#   → State 40: 3 times (prob: 0.27)
#   → State 41: 4 times (prob: 0.36)
#   → State 48: 4 times (prob: 0.36)
#
# State 40, Action 2:
#   → State 32: 7 times (prob: 0.50)
#   → State 41: 4 times (prob: 0.29)
#   → State 48: 3 times (prob: 0.21)
#
# State 40, Action 3:
#   → State 32: 6 times (prob: 0.43)
#   → State 40: 5 times (prob: 0.36)
#   → State 41: 3 times (prob: 0.21)
#
# State 43, Action 2:
#   → State 44: 1 times (prob: 1.00)
#
# State 44, Action 0:
#   → State 36: 1 times (prob: 1.00)
#
# State 44, Action 2:
#   → State 45: 1 times (prob: 1.00)
#
# State 44, Action 3:
#   → State 43: 1 times (prob: 1.00)
#
# State 45, Action 1:
#   → State 46: 1 times (prob: 1.00)
#
# State 47, Action 0:
#   → State 39: 1 times (prob: 0.33)
#   → State 46: 2 times (prob: 0.67)
#
# State 47, Action 1:
#   → State 46: 1 times (prob: 0.33)
#   → State 55: 2 times (prob: 0.67)
#
# State 47, Action 2:
#   → State 47: 1 times (prob: 1.00)
#
# State 47, Action 3:
#   → State 47: 2 times (prob: 1.00)
#
# State 48, Action 0:
#   → State 56: 1 times (prob: 1.00)
#
# State 48, Action 1:
#   → State 48: 1 times (prob: 0.20)
#   → State 49: 3 times (prob: 0.60)
#   → State 56: 1 times (prob: 0.20)
#
# State 48, Action 2:
#   → State 40: 4 times (prob: 0.80)
#   → State 49: 1 times (prob: 0.20)
#
# State 48, Action 3:
#   → State 40: 1 times (prob: 0.25)
#   → State 48: 1 times (prob: 0.25)
#   → State 49: 2 times (prob: 0.50)
#
# State 55, Action 1:
#   → State 63: 1 times (prob: 1.00)
#
# State 55, Action 3:
#   → State 47: 1 times (prob: 1.00)
#
# State 56, Action 0:
#   → State 56: 1 times (prob: 1.00)
#
# State 56, Action 3:
#   → State 48: 1 times (prob: 0.50)
#   → State 57: 1 times (prob: 0.50)
#
# State 57, Action 2:
#   → State 58: 1 times (prob: 1.00)
#
# State 58, Action 1:
#   → State 59: 1 times (prob: 1.00)
#
#
# Rewards tabel:
#
# Rewards:
#
# State 0, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 0, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 0, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 0, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 1, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 1, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 1, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 1, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 2, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 2, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 2, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 2, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 3, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 3, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 3, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 3, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 4, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 4, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 4, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 4, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 5, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 5, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 5, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 5, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 6, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 6, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 6, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 6, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 7, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 7, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 7, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 7, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 8, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 8, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 8, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 8, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 9, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 9, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 9, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 9, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 10, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 10, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 10, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 10, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 11, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 11, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 11, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 11, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 12, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 12, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 12, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 12, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 13, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 13, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 13, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 13, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 14, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 14, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 14, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 14, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 15, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 15, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 15, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 15, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 16, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 16, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 16, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 16, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 17, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 17, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 17, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 17, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 18, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 18, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 18, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 18, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 20, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 20, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 20, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 20, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 21, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 21, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 21, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 21, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 22, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 22, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 22, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 22, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 23, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 23, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 23, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 23, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 24, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 24, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 24, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 24, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 25, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 25, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 25, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 25, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 26, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 26, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 26, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 26, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 27, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 27, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 27, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 27, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 28, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 28, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 28, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 28, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 30, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 30, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 30, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 30, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 31, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 31, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 31, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 31, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 32, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 32, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 32, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 32, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 33, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 33, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 33, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 33, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 34, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 34, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 34, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 34, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 36, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 36, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 36, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 36, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 37, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 37, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 38, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 38, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 38, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 38, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 39, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 39, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 39, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 39, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 40, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 40, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 40, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 40, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 43, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 44, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 44, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 44, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 45, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 47, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 47, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 47, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 47, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 48, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 48, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 48, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 48, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 55, Action 1:
#   Mean: 1.00
#   Std: 0.00
#   Min: 1.00
#   Max: 1.00
#
# State 55, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 56, Action 0:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 56, Action 3:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 57, Action 2:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00
#
# State 58, Action 1:
#   Mean: 0.00
#   Std: 0.00
#   Min: 0.00
#   Max: 0.00

# %%
scenario_name = exp_params['scenario_name']
exp_ids = {
    exp_params['algorithm_name']: [exp_params['exp_id']]
}

display_validation_plot(scenarios_dir, scenario_name, exp_ids)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-64-a66a89755bbb> in <cell line: 6>()
#       4 }
#       5
# ----> 6 display_validation_plot(scenarios_dir, scenario_name, exp_ids)
#
# <ipython-input-11-f847f2fb8548> in display_validation_plot(scenarios_dir, scenario_name, exp_ids)
#      22             for iter_name in os.listdir(training_dir):
#      23                 iter_metrics_path = os.path.join(training_dir, iter_name, 'training_iter_metrics.json')
# ---> 24                 with open(iter_metrics_path, 'r') as f:
#      25                     iter_metrics = json.load(f)
#      26                 exp_win_shares.append(iter_metrics['win_share'])
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/RL/scenarios/8x8_stochastic/dynaq/exp-2312-014756/training/iter-1/training_iter_metrics.json'

# %% [markdown]
# ### Оценка агента

# %%
train_eps_num = 4000

load_best_agent_for_train_step(train_eps_num,
                               exp_params['training']['iteration_count'],
                               exp_dirs['training'],
                               dynaq_agent)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-65-0afc437224ca> in <cell line: 3>()
#       1 train_eps_num = 4000
#       2
# ----> 3 load_best_agent_for_train_step(train_eps_num,
#       4                                exp_params['training']['iteration_count'],
#       5                                exp_dirs['training'],
#
# <ipython-input-12-e61366a0bb82> in load_best_agent_for_train_step(train_eps_num, iteration_count, training_dir, agent)
#       7         eps_dir = os.path.join(iter_dir, f'eps-{train_eps_num}')
#       8         val_metrics_path = os.path.join(eps_dir, 'validation_metrics.json')
# ----> 9         with open(val_metrics_path, 'r') as f:
#      10             val_metrics = json.load(f)
#      11         if val_metrics['win_share'] > best_win_share and val_metrics['avg_step_count'] < best_avg_step_count:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/RL/scenarios/8x8_stochastic/dynaq/exp-2312-014756/training/iter-1/eps-4000/validation_metrics.json'

# %%
dynaq_agent.display_q_table()

# %%
env = create_environment(map_size=MAP_SIZE, stochastic_env=STOCHASTIC_ENV)
evaluate_agent(env, dynaq_agent, exp_params, exp_dirs)
env.close()

# %%
show_episode_records(exp_dirs['evaluation'])

# %% [markdown]
# ## Сравнение эффективности процесса обучения

# %%
scenario_name = '8x8_stochastic'
exp_ids = {
    'qtable': ['exp-1601-163730', 'exp-...'],
    'dynaq': ['exp-1601-170633']
}

display_validation_plot(scenarios_dir, scenario_name, exp_ids)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-66-e321df07d90b> in <cell line: 7>()
#       5 }
#       6
# ----> 7 display_validation_plot(scenarios_dir, scenario_name, exp_ids)
#
# <ipython-input-11-f847f2fb8548> in display_validation_plot(scenarios_dir, scenario_name, exp_ids)
#      10             training_dir = os.path.join(exp_dir, 'training')
#      11
# ---> 12             with open(exp_params_path, 'r') as f:
#      13                 exp_params = json.load(f)
#      14             total_eps_count = exp_params['training']['episode_count']
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/RL/scenarios/8x8_stochastic/qtable/exp-1601-163730/experiment_params.json'
